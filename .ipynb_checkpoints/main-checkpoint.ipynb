# %%
import numpy as np
import cv2
from collections import Counter, defaultdict
 
# location of first frame
firstframe_path =r'FrameNo0.png'

firstframe = cv2.imread(firstframe_path)
firstframe_gray = cv2.cvtColor(firstframe, cv2.COLOR_BGR2GRAY)
firstframe_blur = cv2.GaussianBlur(firstframe_gray,(21,21),0)

#---------------------------------
#size the window first
#---------------------------------
cv2.namedWindow('CannyEdgeDet',cv2.WINDOW_NORMAL)
cv2.namedWindow('Abandoned Object Detection',cv2.WINDOW_NORMAL)
cv2.namedWindow('Morph_CLOSE',cv2.WINDOW_NORMAL)

# location of video
file_path =r'video1.avi'

cap = cv2.VideoCapture(file_path)

consecutiveframe=20

track_temp=[]
track_master=[]
track_temp2=[]

top_contour_dict = defaultdict(int)
obj_detected_dict = defaultdict(int)

frameno = 0
while (cap.isOpened()):
    ret, frame = cap.read()
    cv2.imshow('main',frame)
    
    if ret==0:
        break
    
    frameno = frameno + 1
    #cv2.putText(frame,'%s%.f'%('Frameno:',frameno), (400,50),cv2.FONT_HERSHEY_SIMPLEX, 1, (255,255,255),2)
    
    frame_gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
    frame_blur = cv2.GaussianBlur(frame_gray,(21,21),0)
     
    frame_diff = cv2.absdiff(firstframe, frame)
  
    #Canny Edge Detection
    edged = cv2.Canny(frame_diff,10,200) #any gradient between 30 and 150 are considered edges
    cv2.imshow('CannyEdgeDet',edged)
    kernel2 = np.ones((5,5),np.uint8) #higher the kernel, eg (10,10), more will be eroded or dilated
    thresh2 = cv2.morphologyEx(edged,cv2.MORPH_CLOSE, kernel2,iterations=2)
    cv2.imshow('Morph_Close', thresh2)
    
    #Create a copy of the thresh to find contours    
    #(_,cnts, _) = cv2.findContours(thresh2.copy(), cv2.RETR_EXTERNAL,cv2.CHAIN_APPROX_SIMPLE)
    (cnts, _) = cv2.findContours(thresh2, cv2.RETR_TREE, cv2.CHAIN_APPROX_SIMPLE)
    mycnts =[] # every new frame, set to empty list. 
    # loop over the contours
    for c in cnts:


        # Calculate Centroid using cv2.moments
        M = cv2.moments(c)
        if M['m00'] == 0: 
            pass
        else:
            cx = int(M['m10']/M['m00'])
            cy = int(M['m01']/M['m00'])


            #----------------------------------------------------------------
            # Set contour criteria
            #----------------------------------------------------------------
            
            if cv2.contourArea(c) < 200 or cv2.contourArea(c)>20000:
                pass
            else:
                mycnts.append(c)
                  
                # compute the bounding box for the contour, draw it on the frame,
                # and update the text
                (x, y, w, h) = cv2.boundingRect(c)
                #cv2.rectangle(frame, (x, y), (x + w, y + h), (0, 255, 0), 2)
                #cv2.putText(frame,'C %s,%s,%.0f'%(cx,cy,cx+cy), (cx,cy),cv2.FONT_HERSHEY_SIMPLEX, 1, (0,0,0),2) 
                
                
                #Store the cx+cy, a single value into a list ; max length of 10000
                #Once hit 10000, tranfer top 20 points to dictionary ; empty list
                sumcxcy=cx+cy
                
                
                
                #track_list.append(cx+cy)
                track_temp.append([cx+cy,frameno])
                
                
                track_master.append([cx+cy,frameno])
                countuniqueframe = set(j for i, j in track_master) # get a set of unique frameno. then len(countuniqueframe)
                
                #----------------------------------------------------------------
                # Store history of frames ; no. of frames stored set by 'consecutiveframe' ;
                # if no. of no. of unique frames > consecutiveframes, then 'pop or remove' the earliest frame ; defined by
                # minframeno. Objective is to count the same values occurs in all the frames under this list. if yes, 
                # it is likely that it is a stationary object and not a passing object (walking) 
                # And the value is stored separately in top_contour_dict , and counted each time. This dict is the master
                # dict to store the list of suspecious object. Ideally, it should be a short list. if there is a long list
                # there will be many false detection. To keep the list short, increase the 'consecutiveframe'.
                # Keep the number of frames to , remove the minframeno.; but hard to remove, rather form a new list without
                #the minframeno.
                #----------------------------------------------------------------
                if len(countuniqueframe)>consecutiveframe or False: 
                    minframeno=min(j for i, j in track_master)
                    for i, j in track_master:
                        if j != minframeno: # get a new list. omit the those with the minframeno
                            track_temp2.append([i,j])
                
                    track_master=list(track_temp2) # transfer to the master list
                    track_temp2=[]
                    
                
                #print 'After',track_master
                
                #count each of the sumcxcy
                #if the same sumcxcy occurs in all the frames, store in master contour dictionary, add 1
                
                countcxcy = Counter(i for i, j in track_master)
                #print countcxcy
                #example countcxcy : Counter({544: 1, 537: 1, 530: 1, 523: 1, 516: 1})
                #if j which is the count occurs in all the frame, store the sumcxcy in dictionary, add 1
                for i,j in countcxcy.items(): 
                    if j>=consecutiveframe:
                        top_contour_dict[i] += 1
  
                
                if sumcxcy in top_contour_dict:
                    if top_contour_dict[sumcxcy]>100:
                        cv2.rectangle(frame, (x, y), (x + w, y + h), (255, 0, 0), 3)
                        cv2.putText(frame,'%s'%('Abandoned object detected'), (cx,cy),cv2.FONT_HERSHEY_SIMPLEX, 1, (255,255,255),2)
                        print ('Detected : ', sumcxcy,frameno, obj_detected_dict)
                        
                        # Store those objects that are detected, and store the last frame that it happened.
                        # Need to find a way to clean the top_contour_dict, else contour will be detected after the 
                        # object is removed because the value is still in the dict.
                        # Method is to record the last frame that the object is detected with the Current Frame (frameno)
                        # if Current Frame - Last Frame detected > some big number say 100 x 3, then it means that 
                        # object may have been removed because it has not been detected for 100x3 frames.
                        
                        obj_detected_dict[sumcxcy]=frameno

    for i, j in obj_detected_dict.items():
        if frameno - obj_detected_dict[i]>200:
            print ('PopBefore',i, obj_detected_dict[i],frameno,obj_detected_dict)
            print ('PopBefore : top_contour :',top_contour_dict)
            obj_detected_dict.pop(i)
            
            # Set the count for eg 448 to zero. because it has not be 'activated' for 200 frames. Likely, to have been removed.
            top_contour_dict[i]=0
            print ('PopAfter',i, obj_detected_dict[i],frameno,obj_detected_dict)
            print ('PopAfter : top_contour :',top_contour_dict)

                        
    
    
    cv2.imshow('Abandoned Object Detection',frame)
         
    
    
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

    
cap.release()
cv2.destroyAllWindows()
# Out:
# Detected :  488 1480 defaultdict(<class 'int'>, {})
# Detected :  488 1481 defaultdict(<class 'int'>, {488: 1480})
# Detected :  488 1482 defaultdict(<class 'int'>, {488: 1481})
# Detected :  488 1483 defaultdict(<class 'int'>, {488: 1482})
# Detected :  488 1484 defaultdict(<class 'int'>, {488: 1483})
# Detected :  488 1485 defaultdict(<class 'int'>, {488: 1484})
# Detected :  488 1486 defaultdict(<class 'int'>, {488: 1485})
# Detected :  488 1487 defaultdict(<class 'int'>, {488: 1486})
# Detected :  488 1494 defaultdict(<class 'int'>, {488: 1487})
# Detected :  488 1495 defaultdict(<class 'int'>, {488: 1494})
# Detected :  488 1496 defaultdict(<class 'int'>, {488: 1495})
# Detected :  488 1497 defaultdict(<class 'int'>, {488: 1496})
# Detected :  488 1498 defaultdict(<class 'int'>, {488: 1497})
# Detected :  488 1499 defaultdict(<class 'int'>, {488: 1498})
# Detected :  488 1571 defaultdict(<class 'int'>, {488: 1499})
# Detected :  488 1572 defaultdict(<class 'int'>, {488: 1571})
# Detected :  488 1628 defaultdict(<class 'int'>, {488: 1572})
# Detected :  488 1629 defaultdict(<class 'int'>, {488: 1628})
# Detected :  488 1630 defaultdict(<class 'int'>, {488: 1629})
# Detected :  502 1658 defaultdict(<class 'int'>, {488: 1630})
# Detected :  488 1658 defaultdict(<class 'int'>, {488: 1630, 502: 1658})
# Detected :  502 1659 defaultdict(<class 'int'>, {488: 1658, 502: 1658})
# Detected :  488 1659 defaultdict(<class 'int'>, {488: 1658, 502: 1659})
# Detected :  502 1660 defaultdict(<class 'int'>, {488: 1659, 502: 1659})
# Detected :  488 1660 defaultdict(<class 'int'>, {488: 1659, 502: 1660})
# Detected :  502 1661 defaultdict(<class 'int'>, {488: 1660, 502: 1660})
# Detected :  502 1662 defaultdict(<class 'int'>, {488: 1660, 502: 1661})
# Detected :  502 1663 defaultdict(<class 'int'>, {488: 1660, 502: 1662})
# Detected :  502 1664 defaultdict(<class 'int'>, {488: 1660, 502: 1663})
# Detected :  502 1665 defaultdict(<class 'int'>, {488: 1660, 502: 1664})
# Detected :  502 1666 defaultdict(<class 'int'>, {488: 1660, 502: 1665})
# Detected :  488 1666 defaultdict(<class 'int'>, {488: 1660, 502: 1666})
# Detected :  502 1667 defaultdict(<class 'int'>, {488: 1666, 502: 1666})
# Detected :  502 1668 defaultdict(<class 'int'>, {488: 1666, 502: 1667})
# Detected :  502 1669 defaultdict(<class 'int'>, {488: 1666, 502: 1668})
# Detected :  502 1670 defaultdict(<class 'int'>, {488: 1666, 502: 1669})
# Detected :  502 1671 defaultdict(<class 'int'>, {488: 1666, 502: 1670})
# Detected :  502 1672 defaultdict(<class 'int'>, {488: 1666, 502: 1671})
# Detected :  502 1673 defaultdict(<class 'int'>, {488: 1666, 502: 1672})
# Detected :  502 1675 defaultdict(<class 'int'>, {488: 1666, 502: 1673})
# Detected :  502 1676 defaultdict(<class 'int'>, {488: 1666, 502: 1675})
# Detected :  502 1677 defaultdict(<class 'int'>, {488: 1666, 502: 1676})
# Detected :  502 1678 defaultdict(<class 'int'>, {488: 1666, 502: 1677})
# Detected :  502 1679 defaultdict(<class 'int'>, {488: 1666, 502: 1678})
# Detected :  502 1680 defaultdict(<class 'int'>, {488: 1666, 502: 1679})
# Detected :  502 1681 defaultdict(<class 'int'>, {488: 1666, 502: 1680})
# Detected :  502 1682 defaultdict(<class 'int'>, {488: 1666, 502: 1681})
# Detected :  502 1683 defaultdict(<class 'int'>, {488: 1666, 502: 1682})
# Detected :  502 1684 defaultdict(<class 'int'>, {488: 1666, 502: 1683})
# Detected :  502 1685 defaultdict(<class 'int'>, {488: 1666, 502: 1684})
# Detected :  502 1686 defaultdict(<class 'int'>, {488: 1666, 502: 1685})
# Detected :  502 1687 defaultdict(<class 'int'>, {488: 1666, 502: 1686})
# Detected :  502 1688 defaultdict(<class 'int'>, {488: 1666, 502: 1687})
# Detected :  502 1689 defaultdict(<class 'int'>, {488: 1666, 502: 1688})
# Detected :  502 1690 defaultdict(<class 'int'>, {488: 1666, 502: 1689})
# Detected :  502 1691 defaultdict(<class 'int'>, {488: 1666, 502: 1690})
# Detected :  502 1692 defaultdict(<class 'int'>, {488: 1666, 502: 1691})
# Detected :  502 1693 defaultdict(<class 'int'>, {488: 1666, 502: 1692})
# Detected :  502 1694 defaultdict(<class 'int'>, {488: 1666, 502: 1693})
# Detected :  502 1695 defaultdict(<class 'int'>, {488: 1666, 502: 1694})
# Detected :  502 1696 defaultdict(<class 'int'>, {488: 1666, 502: 1695})
# Detected :  502 1697 defaultdict(<class 'int'>, {488: 1666, 502: 1696})
# Detected :  502 1698 defaultdict(<class 'int'>, {488: 1666, 502: 1697})
# Detected :  502 1699 defaultdict(<class 'int'>, {488: 1666, 502: 1698})
# Detected :  502 1700 defaultdict(<class 'int'>, {488: 1666, 502: 1699})
# Detected :  502 1701 defaultdict(<class 'int'>, {488: 1666, 502: 1700})
# Detected :  502 1702 defaultdict(<class 'int'>, {488: 1666, 502: 1701})
# Detected :  502 1703 defaultdict(<class 'int'>, {488: 1666, 502: 1702})
# Detected :  502 1704 defaultdict(<class 'int'>, {488: 1666, 502: 1703})
# Detected :  502 1705 defaultdict(<class 'int'>, {488: 1666, 502: 1704})
# Detected :  502 1706 defaultdict(<class 'int'>, {488: 1666, 502: 1705})
# Detected :  502 1707 defaultdict(<class 'int'>, {488: 1666, 502: 1706})
# Detected :  502 1708 defaultdict(<class 'int'>, {488: 1666, 502: 1707})
# Detected :  502 1709 defaultdict(<class 'int'>, {488: 1666, 502: 1708})
# Detected :  502 1710 defaultdict(<class 'int'>, {488: 1666, 502: 1709})
# Detected :  488 1710 defaultdict(<class 'int'>, {488: 1666, 502: 1710})
# Detected :  502 1711 defaultdict(<class 'int'>, {488: 1710, 502: 1710})
# Detected :  488 1711 defaultdict(<class 'int'>, {488: 1710, 502: 1711})
# Detected :  502 1712 defaultdict(<class 'int'>, {488: 1711, 502: 1711})
# Detected :  488 1712 defaultdict(<class 'int'>, {488: 1711, 502: 1712})
# Detected :  502 1713 defaultdict(<class 'int'>, {488: 1712, 502: 1712})
# Detected :  488 1713 defaultdict(<class 'int'>, {488: 1712, 502: 1713})
# Detected :  502 1714 defaultdict(<class 'int'>, {488: 1713, 502: 1713})
# Detected :  502 1715 defaultdict(<class 'int'>, {488: 1713, 502: 1714})
# Detected :  488 1715 defaultdict(<class 'int'>, {488: 1713, 502: 1715})
# Detected :  502 1716 defaultdict(<class 'int'>, {488: 1715, 502: 1715})
# Detected :  488 1716 defaultdict(<class 'int'>, {488: 1715, 502: 1716})
# Detected :  502 1717 defaultdict(<class 'int'>, {488: 1716, 502: 1716})
# Detected :  488 1717 defaultdict(<class 'int'>, {488: 1716, 502: 1717})
# Detected :  502 1718 defaultdict(<class 'int'>, {488: 1717, 502: 1717})
# Detected :  488 1718 defaultdict(<class 'int'>, {488: 1717, 502: 1718})
# Detected :  502 1719 defaultdict(<class 'int'>, {488: 1718, 502: 1718})
# Detected :  488 1719 defaultdict(<class 'int'>, {488: 1718, 502: 1719})
# Detected :  502 1720 defaultdict(<class 'int'>, {488: 1719, 502: 1719})
# Detected :  488 1720 defaultdict(<class 'int'>, {488: 1719, 502: 1720})
# Detected :  502 1721 defaultdict(<class 'int'>, {488: 1720, 502: 1720})
# Detected :  488 1721 defaultdict(<class 'int'>, {488: 1720, 502: 1721})
# Detected :  502 1722 defaultdict(<class 'int'>, {488: 1721, 502: 1721})
# Detected :  488 1722 defaultdict(<class 'int'>, {488: 1721, 502: 1722})
# Detected :  502 1723 defaultdict(<class 'int'>, {488: 1722, 502: 1722})
# Detected :  488 1723 defaultdict(<class 'int'>, {488: 1722, 502: 1723})
# Detected :  502 1724 defaultdict(<class 'int'>, {488: 1723, 502: 1723})
# Detected :  488 1724 defaultdict(<class 'int'>, {488: 1723, 502: 1724})
# Detected :  502 1725 defaultdict(<class 'int'>, {488: 1724, 502: 1724})
# Detected :  488 1725 defaultdict(<class 'int'>, {488: 1724, 502: 1725})
# Detected :  502 1726 defaultdict(<class 'int'>, {488: 1725, 502: 1725})
# Detected :  488 1726 defaultdict(<class 'int'>, {488: 1725, 502: 1726})
# Detected :  502 1727 defaultdict(<class 'int'>, {488: 1726, 502: 1726})
# Detected :  488 1727 defaultdict(<class 'int'>, {488: 1726, 502: 1727})
# Detected :  502 1728 defaultdict(<class 'int'>, {488: 1727, 502: 1727})
# Detected :  488 1728 defaultdict(<class 'int'>, {488: 1727, 502: 1728})
# Detected :  502 1729 defaultdict(<class 'int'>, {488: 1728, 502: 1728})
# Detected :  488 1729 defaultdict(<class 'int'>, {488: 1728, 502: 1729})
# Detected :  502 1730 defaultdict(<class 'int'>, {488: 1729, 502: 1729})
# Detected :  488 1730 defaultdict(<class 'int'>, {488: 1729, 502: 1730})
# Detected :  502 1731 defaultdict(<class 'int'>, {488: 1730, 502: 1730})
# Detected :  488 1731 defaultdict(<class 'int'>, {488: 1730, 502: 1731})
# Detected :  502 1732 defaultdict(<class 'int'>, {488: 1731, 502: 1731})
# Detected :  488 1732 defaultdict(<class 'int'>, {488: 1731, 502: 1732})
# Detected :  502 1733 defaultdict(<class 'int'>, {488: 1732, 502: 1732})
# Detected :  488 1733 defaultdict(<class 'int'>, {488: 1732, 502: 1733})
# Detected :  502 1734 defaultdict(<class 'int'>, {488: 1733, 502: 1733})
# Detected :  488 1734 defaultdict(<class 'int'>, {488: 1733, 502: 1734})
# Detected :  502 1735 defaultdict(<class 'int'>, {488: 1734, 502: 1734})
# Detected :  488 1735 defaultdict(<class 'int'>, {488: 1734, 502: 1735})
# Detected :  502 1736 defaultdict(<class 'int'>, {488: 1735, 502: 1735})
# Detected :  488 1736 defaultdict(<class 'int'>, {488: 1735, 502: 1736})
# Detected :  502 1737 defaultdict(<class 'int'>, {488: 1736, 502: 1736})
# Detected :  488 1737 defaultdict(<class 'int'>, {488: 1736, 502: 1737})
# Detected :  502 1738 defaultdict(<class 'int'>, {488: 1737, 502: 1737})
# Detected :  488 1738 defaultdict(<class 'int'>, {488: 1737, 502: 1738})
# Detected :  502 1739 defaultdict(<class 'int'>, {488: 1738, 502: 1738})
# Detected :  488 1739 defaultdict(<class 'int'>, {488: 1738, 502: 1739})
# Detected :  502 1740 defaultdict(<class 'int'>, {488: 1739, 502: 1739})
# Detected :  488 1740 defaultdict(<class 'int'>, {488: 1739, 502: 1740})
# Detected :  502 1741 defaultdict(<class 'int'>, {488: 1740, 502: 1740})
# Detected :  488 1741 defaultdict(<class 'int'>, {488: 1740, 502: 1741})
# Detected :  502 1742 defaultdict(<class 'int'>, {488: 1741, 502: 1741})
# Detected :  488 1742 defaultdict(<class 'int'>, {488: 1741, 502: 1742})
# Detected :  502 1743 defaultdict(<class 'int'>, {488: 1742, 502: 1742})
# Detected :  488 1743 defaultdict(<class 'int'>, {488: 1742, 502: 1743})
# Detected :  502 1744 defaultdict(<class 'int'>, {488: 1743, 502: 1743})
# Detected :  488 1744 defaultdict(<class 'int'>, {488: 1743, 502: 1744})
# Detected :  502 1745 defaultdict(<class 'int'>, {488: 1744, 502: 1744})
# Detected :  502 1746 defaultdict(<class 'int'>, {488: 1744, 502: 1745})
# Detected :  502 1747 defaultdict(<class 'int'>, {488: 1744, 502: 1746})
# Detected :  502 1748 defaultdict(<class 'int'>, {488: 1744, 502: 1747})
# Detected :  502 1749 defaultdict(<class 'int'>, {488: 1744, 502: 1748})
# Detected :  502 1750 defaultdict(<class 'int'>, {488: 1744, 502: 1749})
# Detected :  502 1751 defaultdict(<class 'int'>, {488: 1744, 502: 1750})
# Detected :  502 1752 defaultdict(<class 'int'>, {488: 1744, 502: 1751})
# Detected :  502 1753 defaultdict(<class 'int'>, {488: 1744, 502: 1752})
# Detected :  502 1754 defaultdict(<class 'int'>, {488: 1744, 502: 1753})
# Detected :  488 1771 defaultdict(<class 'int'>, {488: 1744, 502: 1754})
# Detected :  488 1772 defaultdict(<class 'int'>, {488: 1771, 502: 1754})
# Detected :  488 1773 defaultdict(<class 'int'>, {488: 1772, 502: 1754})
# Detected :  488 1774 defaultdict(<class 'int'>, {488: 1773, 502: 1754})
# Detected :  488 1776 defaultdict(<class 'int'>, {488: 1774, 502: 1754})
# Detected :  502 1776 defaultdict(<class 'int'>, {488: 1776, 502: 1754})
# Detected :  488 1777 defaultdict(<class 'int'>, {488: 1776, 502: 1776})
# Detected :  488 1778 defaultdict(<class 'int'>, {488: 1777, 502: 1776})
# Detected :  502 1805 defaultdict(<class 'int'>, {488: 1778, 502: 1776})
# Detected :  488 1815 defaultdict(<class 'int'>, {488: 1778, 502: 1805})
# Detected :  488 1816 defaultdict(<class 'int'>, {488: 1815, 502: 1805})
# Detected :  488 1817 defaultdict(<class 'int'>, {488: 1816, 502: 1805})
# Detected :  488 1818 defaultdict(<class 'int'>, {488: 1817, 502: 1805})
# Detected :  488 1819 defaultdict(<class 'int'>, {488: 1818, 502: 1805})
# Detected :  488 1820 defaultdict(<class 'int'>, {488: 1819, 502: 1805})
# Detected :  488 1821 defaultdict(<class 'int'>, {488: 1820, 502: 1805})
# Detected :  488 1822 defaultdict(<class 'int'>, {488: 1821, 502: 1805})
# Detected :  488 1823 defaultdict(<class 'int'>, {488: 1822, 502: 1805})
# Detected :  488 1824 defaultdict(<class 'int'>, {488: 1823, 502: 1805})
# Detected :  488 1825 defaultdict(<class 'int'>, {488: 1824, 502: 1805})
# Detected :  488 1826 defaultdict(<class 'int'>, {488: 1825, 502: 1805})
# Detected :  488 1884 defaultdict(<class 'int'>, {488: 1826, 502: 1805})
# Detected :  488 1890 defaultdict(<class 'int'>, {488: 1884, 502: 1805})
# Detected :  488 1891 defaultdict(<class 'int'>, {488: 1890, 502: 1805})
# Detected :  488 1892 defaultdict(<class 'int'>, {488: 1891, 502: 1805})
# Detected :  488 1893 defaultdict(<class 'int'>, {488: 1892, 502: 1805})
# Detected :  488 1894 defaultdict(<class 'int'>, {488: 1893, 502: 1805})
# Detected :  488 1899 defaultdict(<class 'int'>, {488: 1894, 502: 1805})
# Detected :  488 1900 defaultdict(<class 'int'>, {488: 1899, 502: 1805})
# Detected :  488 1901 defaultdict(<class 'int'>, {488: 1900, 502: 1805})
# Detected :  488 1902 defaultdict(<class 'int'>, {488: 1901, 502: 1805})
# Detected :  488 1911 defaultdict(<class 'int'>, {488: 1902, 502: 1805})
# Detected :  488 1912 defaultdict(<class 'int'>, {488: 1911, 502: 1805})
# Detected :  488 1913 defaultdict(<class 'int'>, {488: 1912, 502: 1805})
# Detected :  488 1914 defaultdict(<class 'int'>, {488: 1913, 502: 1805})
# Detected :  488 1915 defaultdict(<class 'int'>, {488: 1914, 502: 1805})
# Detected :  488 1916 defaultdict(<class 'int'>, {488: 1915, 502: 1805})
# Detected :  488 1917 defaultdict(<class 'int'>, {488: 1916, 502: 1805})
# Detected :  504 1918 defaultdict(<class 'int'>, {488: 1917, 502: 1805})
# Detected :  488 1918 defaultdict(<class 'int'>, {488: 1917, 502: 1805, 504: 1918})
# Detected :  504 1919 defaultdict(<class 'int'>, {488: 1918, 502: 1805, 504: 1918})
# Detected :  488 1919 defaultdict(<class 'int'>, {488: 1918, 502: 1805, 504: 1919})
# Detected :  504 1920 defaultdict(<class 'int'>, {488: 1919, 502: 1805, 504: 1919})
# Detected :  488 1920 defaultdict(<class 'int'>, {488: 1919, 502: 1805, 504: 1920})
# Detected :  504 1921 defaultdict(<class 'int'>, {488: 1920, 502: 1805, 504: 1920})
# Detected :  488 1921 defaultdict(<class 'int'>, {488: 1920, 502: 1805, 504: 1921})
# Detected :  504 1922 defaultdict(<class 'int'>, {488: 1921, 502: 1805, 504: 1921})
# Detected :  488 1922 defaultdict(<class 'int'>, {488: 1921, 502: 1805, 504: 1922})
# Detected :  504 1923 defaultdict(<class 'int'>, {488: 1922, 502: 1805, 504: 1922})
# Detected :  488 1923 defaultdict(<class 'int'>, {488: 1922, 502: 1805, 504: 1923})
# Detected :  504 1924 defaultdict(<class 'int'>, {488: 1923, 502: 1805, 504: 1923})
# Detected :  488 1924 defaultdict(<class 'int'>, {488: 1923, 502: 1805, 504: 1924})
# Detected :  504 1925 defaultdict(<class 'int'>, {488: 1924, 502: 1805, 504: 1924})
# Detected :  488 1925 defaultdict(<class 'int'>, {488: 1924, 502: 1805, 504: 1925})
# Detected :  504 1926 defaultdict(<class 'int'>, {488: 1925, 502: 1805, 504: 1925})
# Detected :  488 1926 defaultdict(<class 'int'>, {488: 1925, 502: 1805, 504: 1926})
# Detected :  504 1927 defaultdict(<class 'int'>, {488: 1926, 502: 1805, 504: 1926})
# Detected :  488 1927 defaultdict(<class 'int'>, {488: 1926, 502: 1805, 504: 1927})
# Detected :  504 1928 defaultdict(<class 'int'>, {488: 1927, 502: 1805, 504: 1927})
# Detected :  488 1928 defaultdict(<class 'int'>, {488: 1927, 502: 1805, 504: 1928})
# Detected :  504 1929 defaultdict(<class 'int'>, {488: 1928, 502: 1805, 504: 1928})
# Detected :  488 1929 defaultdict(<class 'int'>, {488: 1928, 502: 1805, 504: 1929})
# Detected :  504 1930 defaultdict(<class 'int'>, {488: 1929, 502: 1805, 504: 1929})
# Detected :  488 1930 defaultdict(<class 'int'>, {488: 1929, 502: 1805, 504: 1930})
# Detected :  504 1931 defaultdict(<class 'int'>, {488: 1930, 502: 1805, 504: 1930})
# Detected :  488 1931 defaultdict(<class 'int'>, {488: 1930, 502: 1805, 504: 1931})
# Detected :  504 1932 defaultdict(<class 'int'>, {488: 1931, 502: 1805, 504: 1931})
# Detected :  488 1932 defaultdict(<class 'int'>, {488: 1931, 502: 1805, 504: 1932})
# Detected :  504 1933 defaultdict(<class 'int'>, {488: 1932, 502: 1805, 504: 1932})
# Detected :  488 1933 defaultdict(<class 'int'>, {488: 1932, 502: 1805, 504: 1933})
# Detected :  504 1934 defaultdict(<class 'int'>, {488: 1933, 502: 1805, 504: 1933})
# Detected :  504 1935 defaultdict(<class 'int'>, {488: 1933, 502: 1805, 504: 1934})
# Detected :  504 1936 defaultdict(<class 'int'>, {488: 1933, 502: 1805, 504: 1935})
# Detected :  504 1937 defaultdict(<class 'int'>, {488: 1933, 502: 1805, 504: 1936})
# Detected :  504 1938 defaultdict(<class 'int'>, {488: 1933, 502: 1805, 504: 1937})
# Detected :  488 1938 defaultdict(<class 'int'>, {488: 1933, 502: 1805, 504: 1938})
# Detected :  504 1939 defaultdict(<class 'int'>, {488: 1938, 502: 1805, 504: 1938})
# Detected :  504 1940 defaultdict(<class 'int'>, {488: 1938, 502: 1805, 504: 1939})
# Detected :  488 1940 defaultdict(<class 'int'>, {488: 1938, 502: 1805, 504: 1940})
# Detected :  504 1941 defaultdict(<class 'int'>, {488: 1940, 502: 1805, 504: 1940})
# Detected :  488 1941 defaultdict(<class 'int'>, {488: 1940, 502: 1805, 504: 1941})
# Detected :  504 1942 defaultdict(<class 'int'>, {488: 1941, 502: 1805, 504: 1941})
# Detected :  488 1942 defaultdict(<class 'int'>, {488: 1941, 502: 1805, 504: 1942})
# Detected :  504 1943 defaultdict(<class 'int'>, {488: 1942, 502: 1805, 504: 1942})
# Detected :  504 1944 defaultdict(<class 'int'>, {488: 1942, 502: 1805, 504: 1943})
# Detected :  504 1945 defaultdict(<class 'int'>, {488: 1942, 502: 1805, 504: 1944})
# Detected :  488 1945 defaultdict(<class 'int'>, {488: 1942, 502: 1805, 504: 1945})
# Detected :  504 1946 defaultdict(<class 'int'>, {488: 1945, 502: 1805, 504: 1945})
# Detected :  488 1946 defaultdict(<class 'int'>, {488: 1945, 502: 1805, 504: 1946})
# Detected :  504 1947 defaultdict(<class 'int'>, {488: 1946, 502: 1805, 504: 1946})
# Detected :  488 1947 defaultdict(<class 'int'>, {488: 1946, 502: 1805, 504: 1947})
# Detected :  504 1948 defaultdict(<class 'int'>, {488: 1947, 502: 1805, 504: 1947})
# Detected :  488 1948 defaultdict(<class 'int'>, {488: 1947, 502: 1805, 504: 1948})
# Detected :  504 1949 defaultdict(<class 'int'>, {488: 1948, 502: 1805, 504: 1948})
# Detected :  488 1949 defaultdict(<class 'int'>, {488: 1948, 502: 1805, 504: 1949})
# Detected :  504 1950 defaultdict(<class 'int'>, {488: 1949, 502: 1805, 504: 1949})
# Detected :  488 1950 defaultdict(<class 'int'>, {488: 1949, 502: 1805, 504: 1950})
# Detected :  504 1951 defaultdict(<class 'int'>, {488: 1950, 502: 1805, 504: 1950})
# Detected :  488 1951 defaultdict(<class 'int'>, {488: 1950, 502: 1805, 504: 1951})
# Detected :  504 1952 defaultdict(<class 'int'>, {488: 1951, 502: 1805, 504: 1951})
# Detected :  488 1952 defaultdict(<class 'int'>, {488: 1951, 502: 1805, 504: 1952})
# Detected :  504 1953 defaultdict(<class 'int'>, {488: 1952, 502: 1805, 504: 1952})
# Detected :  488 1953 defaultdict(<class 'int'>, {488: 1952, 502: 1805, 504: 1953})
# Detected :  504 1954 defaultdict(<class 'int'>, {488: 1953, 502: 1805, 504: 1953})
# Detected :  488 1954 defaultdict(<class 'int'>, {488: 1953, 502: 1805, 504: 1954})
# Detected :  504 1955 defaultdict(<class 'int'>, {488: 1954, 502: 1805, 504: 1954})
# Detected :  488 1955 defaultdict(<class 'int'>, {488: 1954, 502: 1805, 504: 1955})
# Detected :  504 1956 defaultdict(<class 'int'>, {488: 1955, 502: 1805, 504: 1955})
# Detected :  488 1956 defaultdict(<class 'int'>, {488: 1955, 502: 1805, 504: 1956})
# Detected :  504 1957 defaultdict(<class 'int'>, {488: 1956, 502: 1805, 504: 1956})
# Detected :  488 1957 defaultdict(<class 'int'>, {488: 1956, 502: 1805, 504: 1957})
# Detected :  504 1958 defaultdict(<class 'int'>, {488: 1957, 502: 1805, 504: 1957})
# Detected :  488 1958 defaultdict(<class 'int'>, {488: 1957, 502: 1805, 504: 1958})
# Detected :  504 1959 defaultdict(<class 'int'>, {488: 1958, 502: 1805, 504: 1958})
# Detected :  488 1959 defaultdict(<class 'int'>, {488: 1958, 502: 1805, 504: 1959})
# Detected :  504 1960 defaultdict(<class 'int'>, {488: 1959, 502: 1805, 504: 1959})
# Detected :  488 1960 defaultdict(<class 'int'>, {488: 1959, 502: 1805, 504: 1960})
# Detected :  504 1961 defaultdict(<class 'int'>, {488: 1960, 502: 1805, 504: 1960})
# Detected :  488 1961 defaultdict(<class 'int'>, {488: 1960, 502: 1805, 504: 1961})
# Detected :  504 1962 defaultdict(<class 'int'>, {488: 1961, 502: 1805, 504: 1961})
# Detected :  488 1962 defaultdict(<class 'int'>, {488: 1961, 502: 1805, 504: 1962})
# Detected :  504 1963 defaultdict(<class 'int'>, {488: 1962, 502: 1805, 504: 1962})
# Detected :  488 1963 defaultdict(<class 'int'>, {488: 1962, 502: 1805, 504: 1963})
# Detected :  504 1964 defaultdict(<class 'int'>, {488: 1963, 502: 1805, 504: 1963})
# Detected :  488 1964 defaultdict(<class 'int'>, {488: 1963, 502: 1805, 504: 1964})
# Detected :  504 1965 defaultdict(<class 'int'>, {488: 1964, 502: 1805, 504: 1964})
# Detected :  488 1965 defaultdict(<class 'int'>, {488: 1964, 502: 1805, 504: 1965})
# Detected :  504 1966 defaultdict(<class 'int'>, {488: 1965, 502: 1805, 504: 1965})
# Detected :  488 1966 defaultdict(<class 'int'>, {488: 1965, 502: 1805, 504: 1966})
# Detected :  504 1967 defaultdict(<class 'int'>, {488: 1966, 502: 1805, 504: 1966})
# Detected :  488 1967 defaultdict(<class 'int'>, {488: 1966, 502: 1805, 504: 1967})
# Detected :  504 1968 defaultdict(<class 'int'>, {488: 1967, 502: 1805, 504: 1967})
# Detected :  488 1968 defaultdict(<class 'int'>, {488: 1967, 502: 1805, 504: 1968})
# Detected :  504 1969 defaultdict(<class 'int'>, {488: 1968, 502: 1805, 504: 1968})
# Detected :  504 1970 defaultdict(<class 'int'>, {488: 1968, 502: 1805, 504: 1969})
# Detected :  504 1971 defaultdict(<class 'int'>, {488: 1968, 502: 1805, 504: 1970})
# Detected :  504 1972 defaultdict(<class 'int'>, {488: 1968, 502: 1805, 504: 1971})
# Detected :  504 1973 defaultdict(<class 'int'>, {488: 1968, 502: 1805, 504: 1972})
# Detected :  504 1974 defaultdict(<class 'int'>, {488: 1968, 502: 1805, 504: 1973})
# Detected :  488 1974 defaultdict(<class 'int'>, {488: 1968, 502: 1805, 504: 1974})
# Detected :  504 1975 defaultdict(<class 'int'>, {488: 1974, 502: 1805, 504: 1974})
# Detected :  488 1975 defaultdict(<class 'int'>, {488: 1974, 502: 1805, 504: 1975})
# Detected :  504 1976 defaultdict(<class 'int'>, {488: 1975, 502: 1805, 504: 1975})
# Detected :  488 1976 defaultdict(<class 'int'>, {488: 1975, 502: 1805, 504: 1976})
# Detected :  504 1977 defaultdict(<class 'int'>, {488: 1976, 502: 1805, 504: 1976})
# Detected :  488 1977 defaultdict(<class 'int'>, {488: 1976, 502: 1805, 504: 1977})
# Detected :  504 1978 defaultdict(<class 'int'>, {488: 1977, 502: 1805, 504: 1977})
# Detected :  488 1978 defaultdict(<class 'int'>, {488: 1977, 502: 1805, 504: 1978})
# Detected :  504 1979 defaultdict(<class 'int'>, {488: 1978, 502: 1805, 504: 1978})
# Detected :  504 1980 defaultdict(<class 'int'>, {488: 1978, 502: 1805, 504: 1979})
# Detected :  504 1981 defaultdict(<class 'int'>, {488: 1978, 502: 1805, 504: 1980})
# Detected :  504 1982 defaultdict(<class 'int'>, {488: 1978, 502: 1805, 504: 1981})
# Detected :  504 1983 defaultdict(<class 'int'>, {488: 1978, 502: 1805, 504: 1982})
# Detected :  504 1984 defaultdict(<class 'int'>, {488: 1978, 502: 1805, 504: 1983})
# Detected :  504 1985 defaultdict(<class 'int'>, {488: 1978, 502: 1805, 504: 1984})
# Detected :  504 1986 defaultdict(<class 'int'>, {488: 1978, 502: 1805, 504: 1985})
# Detected :  488 1986 defaultdict(<class 'int'>, {488: 1978, 502: 1805, 504: 1986})
# Detected :  504 1987 defaultdict(<class 'int'>, {488: 1986, 502: 1805, 504: 1986})
# Detected :  488 1987 defaultdict(<class 'int'>, {488: 1986, 502: 1805, 504: 1987})
# Detected :  504 1988 defaultdict(<class 'int'>, {488: 1987, 502: 1805, 504: 1987})
# Detected :  488 1988 defaultdict(<class 'int'>, {488: 1987, 502: 1805, 504: 1988})
# Detected :  504 1989 defaultdict(<class 'int'>, {488: 1988, 502: 1805, 504: 1988})
# Detected :  488 1989 defaultdict(<class 'int'>, {488: 1988, 502: 1805, 504: 1989})
# Detected :  504 1990 defaultdict(<class 'int'>, {488: 1989, 502: 1805, 504: 1989})
# Detected :  488 1990 defaultdict(<class 'int'>, {488: 1989, 502: 1805, 504: 1990})
# Detected :  504 1991 defaultdict(<class 'int'>, {488: 1990, 502: 1805, 504: 1990})
# Detected :  488 1991 defaultdict(<class 'int'>, {488: 1990, 502: 1805, 504: 1991})
# Detected :  488 1992 defaultdict(<class 'int'>, {488: 1991, 502: 1805, 504: 1991})
# Detected :  488 1993 defaultdict(<class 'int'>, {488: 1992, 502: 1805, 504: 1991})
# Detected :  504 1994 defaultdict(<class 'int'>, {488: 1993, 502: 1805, 504: 1991})
# Detected :  488 1994 defaultdict(<class 'int'>, {488: 1993, 502: 1805, 504: 1994})
# Detected :  504 1995 defaultdict(<class 'int'>, {488: 1994, 502: 1805, 504: 1994})
# Detected :  488 1995 defaultdict(<class 'int'>, {488: 1994, 502: 1805, 504: 1995})
# Detected :  504 1996 defaultdict(<class 'int'>, {488: 1995, 502: 1805, 504: 1995})
# Detected :  488 1996 defaultdict(<class 'int'>, {488: 1995, 502: 1805, 504: 1996})
# Detected :  504 1997 defaultdict(<class 'int'>, {488: 1996, 502: 1805, 504: 1996})
# Detected :  488 1997 defaultdict(<class 'int'>, {488: 1996, 502: 1805, 504: 1997})
# Detected :  504 1998 defaultdict(<class 'int'>, {488: 1997, 502: 1805, 504: 1997})
# Detected :  488 1998 defaultdict(<class 'int'>, {488: 1997, 502: 1805, 504: 1998})
# Detected :  504 1999 defaultdict(<class 'int'>, {488: 1998, 502: 1805, 504: 1998})
# Detected :  488 1999 defaultdict(<class 'int'>, {488: 1998, 502: 1805, 504: 1999})
# Detected :  504 2000 defaultdict(<class 'int'>, {488: 1999, 502: 1805, 504: 1999})
# Detected :  488 2000 defaultdict(<class 'int'>, {488: 1999, 502: 1805, 504: 2000})
# Detected :  504 2001 defaultdict(<class 'int'>, {488: 2000, 502: 1805, 504: 2000})
# Detected :  488 2001 defaultdict(<class 'int'>, {488: 2000, 502: 1805, 504: 2001})
# Detected :  504 2002 defaultdict(<class 'int'>, {488: 2001, 502: 1805, 504: 2001})
# Detected :  488 2002 defaultdict(<class 'int'>, {488: 2001, 502: 1805, 504: 2002})
# Detected :  504 2003 defaultdict(<class 'int'>, {488: 2002, 502: 1805, 504: 2002})
# Detected :  488 2003 defaultdict(<class 'int'>, {488: 2002, 502: 1805, 504: 2003})
# Detected :  504 2004 defaultdict(<class 'int'>, {488: 2003, 502: 1805, 504: 2003})
# Detected :  488 2004 defaultdict(<class 'int'>, {488: 2003, 502: 1805, 504: 2004})
# Detected :  504 2005 defaultdict(<class 'int'>, {488: 2004, 502: 1805, 504: 2004})
# Detected :  488 2005 defaultdict(<class 'int'>, {488: 2004, 502: 1805, 504: 2005})
# Detected :  504 2006 defaultdict(<class 'int'>, {488: 2005, 502: 1805, 504: 2005})
# Detected :  488 2006 defaultdict(<class 'int'>, {488: 2005, 502: 1805, 504: 2006})
# PopBefore 502 1805 2006 defaultdict(<class 'int'>, {488: 2006, 502: 1805, 504: 2006})
# PopBefore : top_contour : defaultdict(<class 'int'>, {452: 25, 488: 210, 489: 43, 502: 322, 487: 22, 504: 353, 503: 59})
# PopAfter 502 0 2006 defaultdict(<class 'int'>, {488: 2006, 504: 2006, 502: 0})
# PopAfter : top_contour : defaultdict(<class 'int'>, {452: 25, 488: 210, 489: 43, 502: 0, 487: 22, 504: 353, 503: 59})
# PopBefore 502 0 2006 defaultdict(<class 'int'>, {488: 2006, 504: 2006, 502: 0})
# PopBefore : top_contour : defaultdict(<class 'int'>, {452: 25, 488: 210, 489: 43, 502: 0, 487: 22, 504: 353, 503: 59})
# PopAfter 502 0 2006 defaultdict(<class 'int'>, {488: 2006, 504: 2006, 502: 0})
# PopAfter : top_contour : defaultdict(<class 'int'>, {452: 25, 488: 210, 489: 43, 502: 0, 487: 22, 504: 353, 503: 59})
# PopBefore 502 0 2006 defaultdict(<class 'int'>, {488: 2006, 504: 2006, 502: 0})
# PopBefore : top_contour : defaultdict(<class 'int'>, {452: 25, 488: 210, 489: 43, 502: 0, 487: 22, 504: 353, 503: 59})
# PopAfter 502 0 2006 defaultdict(<class 'int'>, {488: 2006, 504: 2006, 502: 0})
# PopAfter : top_contour : defaultdict(<class 'int'>, {452: 25, 488: 210, 489: 43, 502: 0, 487: 22, 504: 353, 503: 59})
# Detected :  504 2007 defaultdict(<class 'int'>, {488: 2006, 504: 2006, 502: 0})
# Detected :  488 2007 defaultdict(<class 'int'>, {488: 2006, 504: 2007, 502: 0})
# PopBefore 502 0 2007 defaultdict(<class 'int'>, {488: 2007, 504: 2007, 502: 0})
# PopBefore : top_contour : defaultdict(<class 'int'>, {452: 25, 488: 212, 489: 43, 502: 0, 487: 22, 504: 353, 503: 59})
# PopAfter 502 0 2007 defaultdict(<class 'int'>, {488: 2007, 504: 2007, 502: 0})
# PopAfter : top_contour : defaultdict(<class 'int'>, {452: 25, 488: 212, 489: 43, 502: 0, 487: 22, 504: 353, 503: 59})
# PopBefore 502 0 2007 defaultdict(<class 'int'>, {488: 2007, 504: 2007, 502: 0})
# PopBefore : top_contour : defaultdict(<class 'int'>, {452: 25, 488: 212, 489: 43, 502: 0, 487: 22, 504: 353, 503: 59})
# PopAfter 502 0 2007 defaultdict(<class 'int'>, {488: 2007, 504: 2007, 502: 0})
# PopAfter : top_contour : defaultdict(<class 'int'>, {452: 25, 488: 212, 489: 43, 502: 0, 487: 22, 504: 353, 503: 59})
# PopBefore 502 0 2007 defaultdict(<class 'int'>, {488: 2007, 504: 2007, 502: 0})
# PopBefore : top_contour : defaultdict(<class 'int'>, {452: 25, 488: 212, 489: 43, 502: 0, 487: 22, 504: 353, 503: 59})
# PopAfter 502 0 2007 defaultdict(<class 'int'>, {488: 2007, 504: 2007, 502: 0})
# PopAfter : top_contour : defaultdict(<class 'int'>, {452: 25, 488: 212, 489: 43, 502: 0, 487: 22, 504: 353, 503: 59})
# Detected :  504 2008 defaultdict(<class 'int'>, {488: 2007, 504: 2007, 502: 0})
# Detected :  488 2008 defaultdict(<class 'int'>, {488: 2007, 504: 2008, 502: 0})
# PopBefore 502 0 2008 defaultdict(<class 'int'>, {488: 2008, 504: 2008, 502: 0})
# PopBefore : top_contour : defaultdict(<class 'int'>, {452: 25, 488: 214, 489: 43, 502: 0, 487: 22, 504: 353, 503: 59})
# PopAfter 502 0 2008 defaultdict(<class 'int'>, {488: 2008, 504: 2008, 502: 0})
# PopAfter : top_contour : defaultdict(<class 'int'>, {452: 25, 488: 214, 489: 43, 502: 0, 487: 22, 504: 353, 503: 59})
# PopBefore 502 0 2008 defaultdict(<class 'int'>, {488: 2008, 504: 2008, 502: 0})
# PopBefore : top_contour : defaultdict(<class 'int'>, {452: 25, 488: 214, 489: 43, 502: 0, 487: 22, 504: 353, 503: 59})
# PopAfter 502 0 2008 defaultdict(<class 'int'>, {488: 2008, 504: 2008, 502: 0})
# PopAfter : top_contour : defaultdict(<class 'int'>, {452: 25, 488: 214, 489: 43, 502: 0, 487: 22, 504: 353, 503: 59})
# PopBefore 502 0 2008 defaultdict(<class 'int'>, {488: 2008, 504: 2008, 502: 0})
# PopBefore : top_contour : defaultdict(<class 'int'>, {452: 25, 488: 214, 489: 43, 502: 0, 487: 22, 504: 353, 503: 59})
# PopAfter 502 0 2008 defaultdict(<class 'int'>, {488: 2008, 504: 2008, 502: 0})
# PopAfter : top_contour : defaultdict(<class 'int'>, {452: 25, 488: 214, 489: 43, 502: 0, 487: 22, 504: 353, 503: 59})
# Detected :  504 2009 defaultdict(<class 'int'>, {488: 2008, 504: 2008, 502: 0})
# Detected :  488 2009 defaultdict(<class 'int'>, {488: 2008, 504: 2009, 502: 0})
# PopBefore 502 0 2009 defaultdict(<class 'int'>, {488: 2009, 504: 2009, 502: 0})
# PopBefore : top_contour : defaultdict(<class 'int'>, {452: 25, 488: 216, 489: 43, 502: 0, 487: 22, 504: 353, 503: 59})
# PopAfter 502 0 2009 defaultdict(<class 'int'>, {488: 2009, 504: 2009, 502: 0})
# PopAfter : top_contour : defaultdict(<class 'int'>, {452: 25, 488: 216, 489: 43, 502: 0, 487: 22, 504: 353, 503: 59})
# PopBefore 502 0 2009 defaultdict(<class 'int'>, {488: 2009, 504: 2009, 502: 0})
# PopBefore : top_contour : defaultdict(<class 'int'>, {452: 25, 488: 216, 489: 43, 502: 0, 487: 22, 504: 353, 503: 59})
# PopAfter 502 0 2009 defaultdict(<class 'int'>, {488: 2009, 504: 2009, 502: 0})
# PopAfter : top_contour : defaultdict(<class 'int'>, {452: 25, 488: 216, 489: 43, 502: 0, 487: 22, 504: 353, 503: 59})
# PopBefore 502 0 2009 defaultdict(<class 'int'>, {488: 2009, 504: 2009, 502: 0})
# PopBefore : top_contour : defaultdict(<class 'int'>, {452: 25, 488: 216, 489: 43, 502: 0, 487: 22, 504: 353, 503: 59})
# PopAfter 502 0 2009 defaultdict(<class 'int'>, {488: 2009, 504: 2009, 502: 0})
# PopAfter : top_contour : defaultdict(<class 'int'>, {452: 25, 488: 216, 489: 43, 502: 0, 487: 22, 504: 353, 503: 59})
# Detected :  504 2010 defaultdict(<class 'int'>, {488: 2009, 504: 2009, 502: 0})
# Detected :  488 2010 defaultdict(<class 'int'>, {488: 2009, 504: 2010, 502: 0})
# PopBefore 502 0 2010 defaultdict(<class 'int'>, {488: 2010, 504: 2010, 502: 0})
# PopBefore : top_contour : defaultdict(<class 'int'>, {452: 25, 488: 219, 489: 43, 502: 0, 487: 22, 504: 353, 503: 59})
# PopAfter 502 0 2010 defaultdict(<class 'int'>, {488: 2010, 504: 2010, 502: 0})
# PopAfter : top_contour : defaultdict(<class 'int'>, {452: 25, 488: 219, 489: 43, 502: 0, 487: 22, 504: 353, 503: 59})
# PopBefore 502 0 2010 defaultdict(<class 'int'>, {488: 2010, 504: 2010, 502: 0})
# PopBefore : top_contour : defaultdict(<class 'int'>, {452: 25, 488: 219, 489: 43, 502: 0, 487: 22, 504: 353, 503: 59})
# PopAfter 502 0 2010 defaultdict(<class 'int'>, {488: 2010, 504: 2010, 502: 0})
# PopAfter : top_contour : defaultdict(<class 'int'>, {452: 25, 488: 219, 489: 43, 502: 0, 487: 22, 504: 353, 503: 59})
# PopBefore 502 0 2010 defaultdict(<class 'int'>, {488: 2010, 504: 2010, 502: 0})
# PopBefore : top_contour : defaultdict(<class 'int'>, {452: 25, 488: 219, 489: 43, 502: 0, 487: 22, 504: 353, 503: 59})
# PopAfter 502 0 2010 defaultdict(<class 'int'>, {488: 2010, 504: 2010, 502: 0})
# PopAfter : top_contour : defaultdict(<class 'int'>, {452: 25, 488: 219, 489: 43, 502: 0, 487: 22, 504: 353, 503: 59})
# Detected :  504 2011 defaultdict(<class 'int'>, {488: 2010, 504: 2010, 502: 0})
# Detected :  488 2011 defaultdict(<class 'int'>, {488: 2010, 504: 2011, 502: 0})
# PopBefore 502 0 2011 defaultdict(<class 'int'>, {488: 2011, 504: 2011, 502: 0})
# PopBefore : top_contour : defaultdict(<class 'int'>, {452: 25, 488: 223, 489: 43, 502: 0, 487: 22, 504: 353, 503: 59})
# PopAfter 502 0 2011 defaultdict(<class 'int'>, {488: 2011, 504: 2011, 502: 0})
# PopAfter : top_contour : defaultdict(<class 'int'>, {452: 25, 488: 223, 489: 43, 502: 0, 487: 22, 504: 353, 503: 59})
# PopBefore 502 0 2011 defaultdict(<class 'int'>, {488: 2011, 504: 2011, 502: 0})
# PopBefore : top_contour : defaultdict(<class 'int'>, {452: 25, 488: 223, 489: 43, 502: 0, 487: 22, 504: 353, 503: 59})
# PopAfter 502 0 2011 defaultdict(<class 'int'>, {488: 2011, 504: 2011, 502: 0})
# PopAfter : top_contour : defaultdict(<class 'int'>, {452: 25, 488: 223, 489: 43, 502: 0, 487: 22, 504: 353, 503: 59})
# PopBefore 502 0 2011 defaultdict(<class 'int'>, {488: 2011, 504: 2011, 502: 0})
# PopBefore : top_contour : defaultdict(<class 'int'>, {452: 25, 488: 223, 489: 43, 502: 0, 487: 22, 504: 353, 503: 59})
# PopAfter 502 0 2011 defaultdict(<class 'int'>, {488: 2011, 504: 2011, 502: 0})
# PopAfter : top_contour : defaultdict(<class 'int'>, {452: 25, 488: 223, 489: 43, 502: 0, 487: 22, 504: 353, 503: 59})
# Detected :  504 2012 defaultdict(<class 'int'>, {488: 2011, 504: 2011, 502: 0})
# Detected :  488 2012 defaultdict(<class 'int'>, {488: 2011, 504: 2012, 502: 0})
# PopBefore 502 0 2012 defaultdict(<class 'int'>, {488: 2012, 504: 2012, 502: 0})
# PopBefore : top_contour : defaultdict(<class 'int'>, {452: 25, 488: 229, 489: 43, 502: 0, 487: 22, 504: 353, 503: 59})
# PopAfter 502 0 2012 defaultdict(<class 'int'>, {488: 2012, 504: 2012, 502: 0})
# PopAfter : top_contour : defaultdict(<class 'int'>, {452: 25, 488: 229, 489: 43, 502: 0, 487: 22, 504: 353, 503: 59})
# PopBefore 502 0 2012 defaultdict(<class 'int'>, {488: 2012, 504: 2012, 502: 0})
# PopBefore : top_contour : defaultdict(<class 'int'>, {452: 25, 488: 229, 489: 43, 502: 0, 487: 22, 504: 353, 503: 59})
# PopAfter 502 0 2012 defaultdict(<class 'int'>, {488: 2012, 504: 2012, 502: 0})
# PopAfter : top_contour : defaultdict(<class 'int'>, {452: 25, 488: 229, 489: 43, 502: 0, 487: 22, 504: 353, 503: 59})
# PopBefore 502 0 2012 defaultdict(<class 'int'>, {488: 2012, 504: 2012, 502: 0})
# PopBefore : top_contour : defaultdict(<class 'int'>, {452: 25, 488: 229, 489: 43, 502: 0, 487: 22, 504: 353, 503: 59})
# PopAfter 502 0 2012 defaultdict(<class 'int'>, {488: 2012, 504: 2012, 502: 0})
# PopAfter : top_contour : defaultdict(<class 'int'>, {452: 25, 488: 229, 489: 43, 502: 0, 487: 22, 504: 353, 503: 59})
# Detected :  504 2013 defaultdict(<class 'int'>, {488: 2012, 504: 2012, 502: 0})
# Detected :  488 2013 defaultdict(<class 'int'>, {488: 2012, 504: 2013, 502: 0})
# PopBefore 502 0 2013 defaultdict(<class 'int'>, {488: 2013, 504: 2013, 502: 0})
# PopBefore : top_contour : defaultdict(<class 'int'>, {452: 25, 488: 234, 489: 43, 502: 0, 487: 22, 504: 359, 503: 59})
# PopAfter 502 0 2013 defaultdict(<class 'int'>, {488: 2013, 504: 2013, 502: 0})
# PopAfter : top_contour : defaultdict(<class 'int'>, {452: 25, 488: 234, 489: 43, 502: 0, 487: 22, 504: 359, 503: 59})
# PopBefore 502 0 2013 defaultdict(<class 'int'>, {488: 2013, 504: 2013, 502: 0})
# PopBefore : top_contour : defaultdict(<class 'int'>, {452: 25, 488: 234, 489: 43, 502: 0, 487: 22, 504: 359, 503: 59})
# PopAfter 502 0 2013 defaultdict(<class 'int'>, {488: 2013, 504: 2013, 502: 0})
# PopAfter : top_contour : defaultdict(<class 'int'>, {452: 25, 488: 234, 489: 43, 502: 0, 487: 22, 504: 359, 503: 59})
# PopBefore 502 0 2013 defaultdict(<class 'int'>, {488: 2013, 504: 2013, 502: 0})
# PopBefore : top_contour : defaultdict(<class 'int'>, {452: 25, 488: 234, 489: 43, 502: 0, 487: 22, 504: 359, 503: 59})
# PopAfter 502 0 2013 defaultdict(<class 'int'>, {488: 2013, 504: 2013, 502: 0})
# PopAfter : top_contour : defaultdict(<class 'int'>, {452: 25, 488: 234, 489: 43, 502: 0, 487: 22, 504: 359, 503: 59})
# Detected :  504 2014 defaultdict(<class 'int'>, {488: 2013, 504: 2013, 502: 0})
# Detected :  488 2014 defaultdict(<class 'int'>, {488: 2013, 504: 2014, 502: 0})
# PopBefore 502 0 2014 defaultdict(<class 'int'>, {488: 2014, 504: 2014, 502: 0})
# PopBefore : top_contour : defaultdict(<class 'int'>, {452: 25, 488: 241, 489: 43, 502: 0, 487: 22, 504: 367, 503: 59})
# PopAfter 502 0 2014 defaultdict(<class 'int'>, {488: 2014, 504: 2014, 502: 0})
# PopAfter : top_contour : defaultdict(<class 'int'>, {452: 25, 488: 241, 489: 43, 502: 0, 487: 22, 504: 367, 503: 59})
# PopBefore 502 0 2014 defaultdict(<class 'int'>, {488: 2014, 504: 2014, 502: 0})
# PopBefore : top_contour : defaultdict(<class 'int'>, {452: 25, 488: 241, 489: 43, 502: 0, 487: 22, 504: 367, 503: 59})
# PopAfter 502 0 2014 defaultdict(<class 'int'>, {488: 2014, 504: 2014, 502: 0})
# PopAfter : top_contour : defaultdict(<class 'int'>, {452: 25, 488: 241, 489: 43, 502: 0, 487: 22, 504: 367, 503: 59})
# PopBefore 502 0 2014 defaultdict(<class 'int'>, {488: 2014, 504: 2014, 502: 0})
# PopBefore : top_contour : defaultdict(<class 'int'>, {452: 25, 488: 241, 489: 43, 502: 0, 487: 22, 504: 367, 503: 59})
# PopAfter 502 0 2014 defaultdict(<class 'int'>, {488: 2014, 504: 2014, 502: 0})
# PopAfter : top_contour : defaultdict(<class 'int'>, {452: 25, 488: 241, 489: 43, 502: 0, 487: 22, 504: 367, 503: 59})
# Detected :  504 2015 defaultdict(<class 'int'>, {488: 2014, 504: 2014, 502: 0})
# Detected :  488 2015 defaultdict(<class 'int'>, {488: 2014, 504: 2015, 502: 0})
# PopBefore 502 0 2015 defaultdict(<class 'int'>, {488: 2015, 504: 2015, 502: 0})
# PopBefore : top_contour : defaultdict(<class 'int'>, {452: 25, 488: 248, 489: 43, 502: 0, 487: 22, 504: 375, 503: 59})
# PopAfter 502 0 2015 defaultdict(<class 'int'>, {488: 2015, 504: 2015, 502: 0})
# PopAfter : top_contour : defaultdict(<class 'int'>, {452: 25, 488: 248, 489: 43, 502: 0, 487: 22, 504: 375, 503: 59})
# PopBefore 502 0 2015 defaultdict(<class 'int'>, {488: 2015, 504: 2015, 502: 0})
# PopBefore : top_contour : defaultdict(<class 'int'>, {452: 25, 488: 248, 489: 43, 502: 0, 487: 22, 504: 375, 503: 59})
# PopAfter 502 0 2015 defaultdict(<class 'int'>, {488: 2015, 504: 2015, 502: 0})
# PopAfter : top_contour : defaultdict(<class 'int'>, {452: 25, 488: 248, 489: 43, 502: 0, 487: 22, 504: 375, 503: 59})
# PopBefore 502 0 2015 defaultdict(<class 'int'>, {488: 2015, 504: 2015, 502: 0})
# PopBefore : top_contour : defaultdict(<class 'int'>, {452: 25, 488: 248, 489: 43, 502: 0, 487: 22, 504: 375, 503: 59})
# PopAfter 502 0 2015 defaultdict(<class 'int'>, {488: 2015, 504: 2015, 502: 0})
# PopAfter : top_contour : defaultdict(<class 'int'>, {452: 25, 488: 248, 489: 43, 502: 0, 487: 22, 504: 375, 503: 59})
# Detected :  504 2016 defaultdict(<class 'int'>, {488: 2015, 504: 2015, 502: 0})
# Detected :  488 2016 defaultdict(<class 'int'>, {488: 2015, 504: 2016, 502: 0})
# PopBefore 502 0 2016 defaultdict(<class 'int'>, {488: 2016, 504: 2016, 502: 0})
# PopBefore : top_contour : defaultdict(<class 'int'>, {452: 25, 488: 252, 489: 43, 502: 0, 487: 22, 504: 380, 503: 59})
# PopAfter 502 0 2016 defaultdict(<class 'int'>, {488: 2016, 504: 2016, 502: 0})
# PopAfter : top_contour : defaultdict(<class 'int'>, {452: 25, 488: 252, 489: 43, 502: 0, 487: 22, 504: 380, 503: 59})
# PopBefore 502 0 2016 defaultdict(<class 'int'>, {488: 2016, 504: 2016, 502: 0})
# PopBefore : top_contour : defaultdict(<class 'int'>, {452: 25, 488: 252, 489: 43, 502: 0, 487: 22, 504: 380, 503: 59})
# PopAfter 502 0 2016 defaultdict(<class 'int'>, {488: 2016, 504: 2016, 502: 0})
# PopAfter : top_contour : defaultdict(<class 'int'>, {452: 25, 488: 252, 489: 43, 502: 0, 487: 22, 504: 380, 503: 59})
# PopBefore 502 0 2016 defaultdict(<class 'int'>, {488: 2016, 504: 2016, 502: 0})
# PopBefore : top_contour : defaultdict(<class 'int'>, {452: 25, 488: 252, 489: 43, 502: 0, 487: 22, 504: 380, 503: 59})
# PopAfter 502 0 2016 defaultdict(<class 'int'>, {488: 2016, 504: 2016, 502: 0})
# PopAfter : top_contour : defaultdict(<class 'int'>, {452: 25, 488: 252, 489: 43, 502: 0, 487: 22, 504: 380, 503: 59})
# Detected :  504 2017 defaultdict(<class 'int'>, {488: 2016, 504: 2016, 502: 0})
# Detected :  488 2017 defaultdict(<class 'int'>, {488: 2016, 504: 2017, 502: 0})
# PopBefore 502 0 2017 defaultdict(<class 'int'>, {488: 2017, 504: 2017, 502: 0})
# PopBefore : top_contour : defaultdict(<class 'int'>, {452: 25, 488: 257, 489: 43, 502: 0, 487: 22, 504: 386, 503: 59})
# PopAfter 502 0 2017 defaultdict(<class 'int'>, {488: 2017, 504: 2017, 502: 0})
# PopAfter : top_contour : defaultdict(<class 'int'>, {452: 25, 488: 257, 489: 43, 502: 0, 487: 22, 504: 386, 503: 59})
# PopBefore 502 0 2017 defaultdict(<class 'int'>, {488: 2017, 504: 2017, 502: 0})
# PopBefore : top_contour : defaultdict(<class 'int'>, {452: 25, 488: 257, 489: 43, 502: 0, 487: 22, 504: 386, 503: 59})
# PopAfter 502 0 2017 defaultdict(<class 'int'>, {488: 2017, 504: 2017, 502: 0})
# PopAfter : top_contour : defaultdict(<class 'int'>, {452: 25, 488: 257, 489: 43, 502: 0, 487: 22, 504: 386, 503: 59})
# PopBefore 502 0 2017 defaultdict(<class 'int'>, {488: 2017, 504: 2017, 502: 0})
# PopBefore : top_contour : defaultdict(<class 'int'>, {452: 25, 488: 257, 489: 43, 502: 0, 487: 22, 504: 386, 503: 59})
# PopAfter 502 0 2017 defaultdict(<class 'int'>, {488: 2017, 504: 2017, 502: 0})
# PopAfter : top_contour : defaultdict(<class 'int'>, {452: 25, 488: 257, 489: 43, 502: 0, 487: 22, 504: 386, 503: 59})
# Detected :  504 2018 defaultdict(<class 'int'>, {488: 2017, 504: 2017, 502: 0})
# Detected :  488 2018 defaultdict(<class 'int'>, {488: 2017, 504: 2018, 502: 0})
# PopBefore 502 0 2018 defaultdict(<class 'int'>, {488: 2018, 504: 2018, 502: 0})
# PopBefore : top_contour : defaultdict(<class 'int'>, {452: 25, 488: 261, 489: 43, 502: 0, 487: 22, 504: 391, 503: 59})
# PopAfter 502 0 2018 defaultdict(<class 'int'>, {488: 2018, 504: 2018, 502: 0})
# PopAfter : top_contour : defaultdict(<class 'int'>, {452: 25, 488: 261, 489: 43, 502: 0, 487: 22, 504: 391, 503: 59})
# PopBefore 502 0 2018 defaultdict(<class 'int'>, {488: 2018, 504: 2018, 502: 0})
# PopBefore : top_contour : defaultdict(<class 'int'>, {452: 25, 488: 261, 489: 43, 502: 0, 487: 22, 504: 391, 503: 59})
# PopAfter 502 0 2018 defaultdict(<class 'int'>, {488: 2018, 504: 2018, 502: 0})
# PopAfter : top_contour : defaultdict(<class 'int'>, {452: 25, 488: 261, 489: 43, 502: 0, 487: 22, 504: 391, 503: 59})
# PopBefore 502 0 2018 defaultdict(<class 'int'>, {488: 2018, 504: 2018, 502: 0})
# PopBefore : top_contour : defaultdict(<class 'int'>, {452: 25, 488: 261, 489: 43, 502: 0, 487: 22, 504: 391, 503: 59})
# PopAfter 502 0 2018 defaultdict(<class 'int'>, {488: 2018, 504: 2018, 502: 0})
# PopAfter : top_contour : defaultdict(<class 'int'>, {452: 25, 488: 261, 489: 43, 502: 0, 487: 22, 504: 391, 503: 59})
# Detected :  504 2019 defaultdict(<class 'int'>, {488: 2018, 504: 2018, 502: 0})
# Detected :  488 2019 defaultdict(<class 'int'>, {488: 2018, 504: 2019, 502: 0})
# PopBefore 502 0 2019 defaultdict(<class 'int'>, {488: 2019, 504: 2019, 502: 0})
# PopBefore : top_contour : defaultdict(<class 'int'>, {452: 25, 488: 267, 489: 43, 502: 0, 487: 22, 504: 398, 503: 59})
# PopAfter 502 0 2019 defaultdict(<class 'int'>, {488: 2019, 504: 2019, 502: 0})
# PopAfter : top_contour : defaultdict(<class 'int'>, {452: 25, 488: 267, 489: 43, 502: 0, 487: 22, 504: 398, 503: 59})
# PopBefore 502 0 2019 defaultdict(<class 'int'>, {488: 2019, 504: 2019, 502: 0})
# PopBefore : top_contour : defaultdict(<class 'int'>, {452: 25, 488: 267, 489: 43, 502: 0, 487: 22, 504: 398, 503: 59})
# PopAfter 502 0 2019 defaultdict(<class 'int'>, {488: 2019, 504: 2019, 502: 0})
# PopAfter : top_contour : defaultdict(<class 'int'>, {452: 25, 488: 267, 489: 43, 502: 0, 487: 22, 504: 398, 503: 59})
# PopBefore 502 0 2019 defaultdict(<class 'int'>, {488: 2019, 504: 2019, 502: 0})
# PopBefore : top_contour : defaultdict(<class 'int'>, {452: 25, 488: 267, 489: 43, 502: 0, 487: 22, 504: 398, 503: 59})
# PopAfter 502 0 2019 defaultdict(<class 'int'>, {488: 2019, 504: 2019, 502: 0})
# PopAfter : top_contour : defaultdict(<class 'int'>, {452: 25, 488: 267, 489: 43, 502: 0, 487: 22, 504: 398, 503: 59})
# Detected :  504 2020 defaultdict(<class 'int'>, {488: 2019, 504: 2019, 502: 0})
# Detected :  488 2020 defaultdict(<class 'int'>, {488: 2019, 504: 2020, 502: 0})
# PopBefore 502 0 2020 defaultdict(<class 'int'>, {488: 2020, 504: 2020, 502: 0})
# PopBefore : top_contour : defaultdict(<class 'int'>, {452: 25, 488: 273, 489: 43, 502: 0, 487: 22, 504: 405, 503: 59})
# PopAfter 502 0 2020 defaultdict(<class 'int'>, {488: 2020, 504: 2020, 502: 0})
# PopAfter : top_contour : defaultdict(<class 'int'>, {452: 25, 488: 273, 489: 43, 502: 0, 487: 22, 504: 405, 503: 59})
# PopBefore 502 0 2020 defaultdict(<class 'int'>, {488: 2020, 504: 2020, 502: 0})
# PopBefore : top_contour : defaultdict(<class 'int'>, {452: 25, 488: 273, 489: 43, 502: 0, 487: 22, 504: 405, 503: 59})
# PopAfter 502 0 2020 defaultdict(<class 'int'>, {488: 2020, 504: 2020, 502: 0})
# PopAfter : top_contour : defaultdict(<class 'int'>, {452: 25, 488: 273, 489: 43, 502: 0, 487: 22, 504: 405, 503: 59})
# PopBefore 502 0 2020 defaultdict(<class 'int'>, {488: 2020, 504: 2020, 502: 0})
# PopBefore : top_contour : defaultdict(<class 'int'>, {452: 25, 488: 273, 489: 43, 502: 0, 487: 22, 504: 405, 503: 59})
# PopAfter 502 0 2020 defaultdict(<class 'int'>, {488: 2020, 504: 2020, 502: 0})
# PopAfter : top_contour : defaultdict(<class 'int'>, {452: 25, 488: 273, 489: 43, 502: 0, 487: 22, 504: 405, 503: 59})
# Detected :  504 2021 defaultdict(<class 'int'>, {488: 2020, 504: 2020, 502: 0})
# Detected :  488 2021 defaultdict(<class 'int'>, {488: 2020, 504: 2021, 502: 0})
# PopBefore 502 0 2021 defaultdict(<class 'int'>, {488: 2021, 504: 2021, 502: 0})
# PopBefore : top_contour : defaultdict(<class 'int'>, {452: 25, 488: 279, 489: 43, 502: 0, 487: 22, 504: 412, 503: 59})
# PopAfter 502 0 2021 defaultdict(<class 'int'>, {488: 2021, 504: 2021, 502: 0})
# PopAfter : top_contour : defaultdict(<class 'int'>, {452: 25, 488: 279, 489: 43, 502: 0, 487: 22, 504: 412, 503: 59})
# PopBefore 502 0 2021 defaultdict(<class 'int'>, {488: 2021, 504: 2021, 502: 0})
# PopBefore : top_contour : defaultdict(<class 'int'>, {452: 25, 488: 279, 489: 43, 502: 0, 487: 22, 504: 412, 503: 59})
# PopAfter 502 0 2021 defaultdict(<class 'int'>, {488: 2021, 504: 2021, 502: 0})
# PopAfter : top_contour : defaultdict(<class 'int'>, {452: 25, 488: 279, 489: 43, 502: 0, 487: 22, 504: 412, 503: 59})
# PopBefore 502 0 2021 defaultdict(<class 'int'>, {488: 2021, 504: 2021, 502: 0})
# PopBefore : top_contour : defaultdict(<class 'int'>, {452: 25, 488: 279, 489: 43, 502: 0, 487: 22, 504: 412, 503: 59})
# PopAfter 502 0 2021 defaultdict(<class 'int'>, {488: 2021, 504: 2021, 502: 0})
# PopAfter : top_contour : defaultdict(<class 'int'>, {452: 25, 488: 279, 489: 43, 502: 0, 487: 22, 504: 412, 503: 59})
# ...
# PopAfter 502 0 2177 defaultdict(<class 'int'>, {488: 2169, 504: 2177, 502: 0})
# PopAfter : top_contour : defaultdict(<class 'int'>, {452: 25, 488: 651, 489: 43, 502: 0, 487: 22, 504: 496, 503: 59})
# PopBefore 502 0 2177 defaultdict(<class 'int'>, {488: 2169, 504: 2177, 502: 0})
# PopBefore : top_contour : defaultdict(<class 'int'>, {452: 25, 488: 651, 489: 43, 502: 0, 487: 22, 504: 496, 503: 59})
# PopAfter 502 0 2177 defaultdict(<class 'int'>, {488: 2169, 504: 2177, 502: 0})
# PopAfter : top_contour : defaultdict(<class 'int'>, {452: 25, 488: 651, 489: 43, 502: 0, 487: 22, 504: 496, 503: 59})
# Detected :  504 2178 defaultdict(<class 'int'>, {488: 2169, 504: 2177, 502: 0})
# PopBefore 502 0 2178 defaultdict(<class 'int'>, {488: 2169, 504: 2178, 502: 0})
# PopBefore : top_contour : defaultdict(<class 'int'>, {452: 25, 488: 651, 489: 43, 502: 0, 487: 22, 504: 496, 503: 59})
# PopAfter 502 0 2178 defaultdict(<class 'int'>, {488: 2169, 504: 2178, 502: 0})
# PopAfter : top_contour : defaultdict(<class 'int'>, {452: 25, 488: 651, 489: 43, 502: 0, 487: 22, 504: 496, 503: 59})
# PopBefore 502 0 2178 defaultdict(<class 'int'>, {488: 2169, 504: 2178, 502: 0})
# PopBefore : top_contour : defaultdict(<class 'int'>, {452: 25, 488: 651, 489: 43, 502: 0, 487: 22, 504: 496, 503: 59})
# PopAfter 502 0 2178 defaultdict(<class 'int'>, {488: 2169, 504: 2178, 502: 0})
# PopAfter : top_contour : defaultdict(<class 'int'>, {452: 25, 488: 651, 489: 43, 502: 0, 487: 22, 504: 496, 503: 59})
# PopBefore 502 0 2178 defaultdict(<class 'int'>, {488: 2169, 504: 2178, 502: 0})
# PopBefore : top_contour : defaultdict(<class 'int'>, {452: 25, 488: 651, 489: 43, 502: 0, 487: 22, 504: 496, 503: 59})
# PopAfter 502 0 2178 defaultdict(<class 'int'>, {488: 2169, 504: 2178, 502: 0})
# PopAfter : top_contour : defaultdict(<class 'int'>, {452: 25, 488: 651, 489: 43, 502: 0, 487: 22, 504: 496, 503: 59})
# Detected :  504 2179 defaultdict(<class 'int'>, {488: 2169, 504: 2178, 502: 0})
# PopBefore 502 0 2179 defaultdict(<class 'int'>, {488: 2169, 504: 2179, 502: 0})
# PopBefore : top_contour : defaultdict(<class 'int'>, {452: 25, 488: 651, 489: 43, 502: 0, 487: 22, 504: 496, 503: 59})
# PopAfter 502 0 2179 defaultdict(<class 'int'>, {488: 2169, 504: 2179, 502: 0})
# PopAfter : top_contour : defaultdict(<class 'int'>, {452: 25, 488: 651, 489: 43, 502: 0, 487: 22, 504: 496, 503: 59})
# PopBefore 502 0 2179 defaultdict(<class 'int'>, {488: 2169, 504: 2179, 502: 0})
# PopBefore : top_contour : defaultdict(<class 'int'>, {452: 25, 488: 651, 489: 43, 502: 0, 487: 22, 504: 496, 503: 59})
# PopAfter 502 0 2179 defaultdict(<class 'int'>, {488: 2169, 504: 2179, 502: 0})
# PopAfter : top_contour : defaultdict(<class 'int'>, {452: 25, 488: 651, 489: 43, 502: 0, 487: 22, 504: 496, 503: 59})
# PopBefore 502 0 2179 defaultdict(<class 'int'>, {488: 2169, 504: 2179, 502: 0})
# PopBefore : top_contour : defaultdict(<class 'int'>, {452: 25, 488: 651, 489: 43, 502: 0, 487: 22, 504: 496, 503: 59})
# PopAfter 502 0 2179 defaultdict(<class 'int'>, {488: 2169, 504: 2179, 502: 0})
# PopAfter : top_contour : defaultdict(<class 'int'>, {452: 25, 488: 651, 489: 43, 502: 0, 487: 22, 504: 496, 503: 59})
# Detected :  504 2180 defaultdict(<class 'int'>, {488: 2169, 504: 2179, 502: 0})
# PopBefore 502 0 2180 defaultdict(<class 'int'>, {488: 2169, 504: 2180, 502: 0})
# PopBefore : top_contour : defaultdict(<class 'int'>, {452: 25, 488: 651, 489: 43, 502: 0, 487: 22, 504: 496, 503: 59})
# PopAfter 502 0 2180 defaultdict(<class 'int'>, {488: 2169, 504: 2180, 502: 0})
# PopAfter : top_contour : defaultdict(<class 'int'>, {452: 25, 488: 651, 489: 43, 502: 0, 487: 22, 504: 496, 503: 59})
# PopBefore 502 0 2180 defaultdict(<class 'int'>, {488: 2169, 504: 2180, 502: 0})
# PopBefore : top_contour : defaultdict(<class 'int'>, {452: 25, 488: 651, 489: 43, 502: 0, 487: 22, 504: 496, 503: 59})
# PopAfter 502 0 2180 defaultdict(<class 'int'>, {488: 2169, 504: 2180, 502: 0})
# PopAfter : top_contour : defaultdict(<class 'int'>, {452: 25, 488: 651, 489: 43, 502: 0, 487: 22, 504: 496, 503: 59})
# PopBefore 502 0 2180 defaultdict(<class 'int'>, {488: 2169, 504: 2180, 502: 0})
# PopBefore : top_contour : defaultdict(<class 'int'>, {452: 25, 488: 651, 489: 43, 502: 0, 487: 22, 504: 496, 503: 59})
# PopAfter 502 0 2180 defaultdict(<class 'int'>, {488: 2169, 504: 2180, 502: 0})
# PopAfter : top_contour : defaultdict(<class 'int'>, {452: 25, 488: 651, 489: 43, 502: 0, 487: 22, 504: 496, 503: 59})
# Detected :  504 2181 defaultdict(<class 'int'>, {488: 2169, 504: 2180, 502: 0})
# PopBefore 502 0 2181 defaultdict(<class 'int'>, {488: 2169, 504: 2181, 502: 0})
# PopBefore : top_contour : defaultdict(<class 'int'>, {452: 25, 488: 651, 489: 43, 502: 0, 487: 22, 504: 496, 503: 59})
# PopAfter 502 0 2181 defaultdict(<class 'int'>, {488: 2169, 504: 2181, 502: 0})
# PopAfter : top_contour : defaultdict(<class 'int'>, {452: 25, 488: 651, 489: 43, 502: 0, 487: 22, 504: 496, 503: 59})
# PopBefore 502 0 2181 defaultdict(<class 'int'>, {488: 2169, 504: 2181, 502: 0})
# PopBefore : top_contour : defaultdict(<class 'int'>, {452: 25, 488: 651, 489: 43, 502: 0, 487: 22, 504: 496, 503: 59})
# PopAfter 502 0 2181 defaultdict(<class 'int'>, {488: 2169, 504: 2181, 502: 0})
# PopAfter : top_contour : defaultdict(<class 'int'>, {452: 25, 488: 651, 489: 43, 502: 0, 487: 22, 504: 496, 503: 59})
# PopBefore 502 0 2181 defaultdict(<class 'int'>, {488: 2169, 504: 2181, 502: 0})
# PopBefore : top_contour : defaultdict(<class 'int'>, {452: 25, 488: 651, 489: 43, 502: 0, 487: 22, 504: 496, 503: 59})
# PopAfter 502 0 2181 defaultdict(<class 'int'>, {488: 2169, 504: 2181, 502: 0})
# PopAfter : top_contour : defaultdict(<class 'int'>, {452: 25, 488: 651, 489: 43, 502: 0, 487: 22, 504: 496, 503: 59})
# Detected :  504 2182 defaultdict(<class 'int'>, {488: 2169, 504: 2181, 502: 0})
# PopBefore 502 0 2182 defaultdict(<class 'int'>, {488: 2169, 504: 2182, 502: 0})
# PopBefore : top_contour : defaultdict(<class 'int'>, {452: 25, 488: 651, 489: 43, 502: 0, 487: 22, 504: 496, 503: 59})
# PopAfter 502 0 2182 defaultdict(<class 'int'>, {488: 2169, 504: 2182, 502: 0})
# PopAfter : top_contour : defaultdict(<class 'int'>, {452: 25, 488: 651, 489: 43, 502: 0, 487: 22, 504: 496, 503: 59})
# PopBefore 502 0 2182 defaultdict(<class 'int'>, {488: 2169, 504: 2182, 502: 0})
# PopBefore : top_contour : defaultdict(<class 'int'>, {452: 25, 488: 651, 489: 43, 502: 0, 487: 22, 504: 496, 503: 59})
# PopAfter 502 0 2182 defaultdict(<class 'int'>, {488: 2169, 504: 2182, 502: 0})
# PopAfter : top_contour : defaultdict(<class 'int'>, {452: 25, 488: 651, 489: 43, 502: 0, 487: 22, 504: 496, 503: 59})
# PopBefore 502 0 2182 defaultdict(<class 'int'>, {488: 2169, 504: 2182, 502: 0})
# PopBefore : top_contour : defaultdict(<class 'int'>, {452: 25, 488: 651, 489: 43, 502: 0, 487: 22, 504: 496, 503: 59})
# PopAfter 502 0 2182 defaultdict(<class 'int'>, {488: 2169, 504: 2182, 502: 0})
# PopAfter : top_contour : defaultdict(<class 'int'>, {452: 25, 488: 651, 489: 43, 502: 0, 487: 22, 504: 496, 503: 59})
# Detected :  504 2183 defaultdict(<class 'int'>, {488: 2169, 504: 2182, 502: 0})
# PopBefore 502 0 2183 defaultdict(<class 'int'>, {488: 2169, 504: 2183, 502: 0})
# PopBefore : top_contour : defaultdict(<class 'int'>, {452: 25, 488: 651, 489: 43, 502: 0, 487: 22, 504: 496, 503: 59})
# PopAfter 502 0 2183 defaultdict(<class 'int'>, {488: 2169, 504: 2183, 502: 0})
# PopAfter : top_contour : defaultdict(<class 'int'>, {452: 25, 488: 651, 489: 43, 502: 0, 487: 22, 504: 496, 503: 59})
# PopBefore 502 0 2183 defaultdict(<class 'int'>, {488: 2169, 504: 2183, 502: 0})
# PopBefore : top_contour : defaultdict(<class 'int'>, {452: 25, 488: 651, 489: 43, 502: 0, 487: 22, 504: 496, 503: 59})
# PopAfter 502 0 2183 defaultdict(<class 'int'>, {488: 2169, 504: 2183, 502: 0})
# PopAfter : top_contour : defaultdict(<class 'int'>, {452: 25, 488: 651, 489: 43, 502: 0, 487: 22, 504: 496, 503: 59})
# PopBefore 502 0 2183 defaultdict(<class 'int'>, {488: 2169, 504: 2183, 502: 0})
# PopBefore : top_contour : defaultdict(<class 'int'>, {452: 25, 488: 651, 489: 43, 502: 0, 487: 22, 504: 496, 503: 59})
# PopAfter 502 0 2183 defaultdict(<class 'int'>, {488: 2169, 504: 2183, 502: 0})
# PopAfter : top_contour : defaultdict(<class 'int'>, {452: 25, 488: 651, 489: 43, 502: 0, 487: 22, 504: 496, 503: 59})
# PopBefore 502 0 2184 defaultdict(<class 'int'>, {488: 2169, 504: 2183, 502: 0})
# PopBefore : top_contour : defaultdict(<class 'int'>, {452: 25, 488: 651, 489: 43, 502: 0, 487: 22, 504: 496, 503: 59})
# PopAfter 502 0 2184 defaultdict(<class 'int'>, {488: 2169, 504: 2183, 502: 0})
# PopAfter : top_contour : defaultdict(<class 'int'>, {452: 25, 488: 651, 489: 43, 502: 0, 487: 22, 504: 496, 503: 59})
# PopBefore 502 0 2184 defaultdict(<class 'int'>, {488: 2169, 504: 2183, 502: 0})
# PopBefore : top_contour : defaultdict(<class 'int'>, {452: 25, 488: 651, 489: 43, 502: 0, 487: 22, 504: 496, 503: 59})
# PopAfter 502 0 2184 defaultdict(<class 'int'>, {488: 2169, 504: 2183, 502: 0})
# PopAfter : top_contour : defaultdict(<class 'int'>, {452: 25, 488: 651, 489: 43, 502: 0, 487: 22, 504: 496, 503: 59})
# PopBefore 502 0 2184 defaultdict(<class 'int'>, {488: 2169, 504: 2183, 502: 0})
# PopBefore : top_contour : defaultdict(<class 'int'>, {452: 25, 488: 651, 489: 43, 502: 0, 487: 22, 504: 496, 503: 59})
# PopAfter 502 0 2184 defaultdict(<class 'int'>, {488: 2169, 504: 2183, 502: 0})
# PopAfter : top_contour : defaultdict(<class 'int'>, {452: 25, 488: 651, 489: 43, 502: 0, 487: 22, 504: 496, 503: 59})
# PopBefore 502 0 2185 defaultdict(<class 'int'>, {488: 2169, 504: 2183, 502: 0})
# PopBefore : top_contour : defaultdict(<class 'int'>, {452: 25, 488: 651, 489: 43, 502: 0, 487: 22, 504: 496, 503: 59})
# PopAfter 502 0 2185 defaultdict(<class 'int'>, {488: 2169, 504: 2183, 502: 0})
# PopAfter : top_contour : defaultdict(<class 'int'>, {452: 25, 488: 651, 489: 43, 502: 0, 487: 22, 504: 496, 503: 59})
# PopBefore 502 0 2185 defaultdict(<class 'int'>, {488: 2169, 504: 2183, 502: 0})
# PopBefore : top_contour : defaultdict(<class 'int'>, {452: 25, 488: 651, 489: 43, 502: 0, 487: 22, 504: 496, 503: 59})
# PopAfter 502 0 2185 defaultdict(<class 'int'>, {488: 2169, 504: 2183, 502: 0})
# PopAfter : top_contour : defaultdict(<class 'int'>, {452: 25, 488: 651, 489: 43, 502: 0, 487: 22, 504: 496, 503: 59})
# PopBefore 502 0 2185 defaultdict(<class 'int'>, {488: 2169, 504: 2183, 502: 0})
# PopBefore : top_contour : defaultdict(<class 'int'>, {452: 25, 488: 651, 489: 43, 502: 0, 487: 22, 504: 496, 503: 59})
# PopAfter 502 0 2185 defaultdict(<class 'int'>, {488: 2169, 504: 2183, 502: 0})
# PopAfter : top_contour : defaultdict(<class 'int'>, {452: 25, 488: 651, 489: 43, 502: 0, 487: 22, 504: 496, 503: 59})
# PopBefore 502 0 2186 defaultdict(<class 'int'>, {488: 2169, 504: 2183, 502: 0})
# PopBefore : top_contour : defaultdict(<class 'int'>, {452: 25, 488: 651, 489: 43, 502: 0, 487: 22, 504: 496, 503: 59})
# PopAfter 502 0 2186 defaultdict(<class 'int'>, {488: 2169, 504: 2183, 502: 0})
# PopAfter : top_contour : defaultdict(<class 'int'>, {452: 25, 488: 651, 489: 43, 502: 0, 487: 22, 504: 496, 503: 59})
# PopBefore 502 0 2186 defaultdict(<class 'int'>, {488: 2169, 504: 2183, 502: 0})
# PopBefore : top_contour : defaultdict(<class 'int'>, {452: 25, 488: 651, 489: 43, 502: 0, 487: 22, 504: 496, 503: 59})
# PopAfter 502 0 2186 defaultdict(<class 'int'>, {488: 2169, 504: 2183, 502: 0})
# PopAfter : top_contour : defaultdict(<class 'int'>, {452: 25, 488: 651, 489: 43, 502: 0, 487: 22, 504: 496, 503: 59})
# PopBefore 502 0 2186 defaultdict(<class 'int'>, {488: 2169, 504: 2183, 502: 0})
# PopBefore : top_contour : defaultdict(<class 'int'>, {452: 25, 488: 651, 489: 43, 502: 0, 487: 22, 504: 496, 503: 59})
# PopAfter 502 0 2186 defaultdict(<class 'int'>, {488: 2169, 504: 2183, 502: 0})
# PopAfter : top_contour : defaultdict(<class 'int'>, {452: 25, 488: 651, 489: 43, 502: 0, 487: 22, 504: 496, 503: 59})
# PopBefore 502 0 2187 defaultdict(<class 'int'>, {488: 2169, 504: 2183, 502: 0})
# PopBefore : top_contour : defaultdict(<class 'int'>, {452: 25, 488: 651, 489: 43, 502: 0, 487: 22, 504: 496, 503: 59})
# PopAfter 502 0 2187 defaultdict(<class 'int'>, {488: 2169, 504: 2183, 502: 0})
# PopAfter : top_contour : defaultdict(<class 'int'>, {452: 25, 488: 651, 489: 43, 502: 0, 487: 22, 504: 496, 503: 59})
# PopBefore 502 0 2187 defaultdict(<class 'int'>, {488: 2169, 504: 2183, 502: 0})
# PopBefore : top_contour : defaultdict(<class 'int'>, {452: 25, 488: 651, 489: 43, 502: 0, 487: 22, 504: 496, 503: 59})
# PopAfter 502 0 2187 defaultdict(<class 'int'>, {488: 2169, 504: 2183, 502: 0})
# PopAfter : top_contour : defaultdict(<class 'int'>, {452: 25, 488: 651, 489: 43, 502: 0, 487: 22, 504: 496, 503: 59})
# PopBefore 502 0 2187 defaultdict(<class 'int'>, {488: 2169, 504: 2183, 502: 0})
# PopBefore : top_contour : defaultdict(<class 'int'>, {452: 25, 488: 651, 489: 43, 502: 0, 487: 22, 504: 496, 503: 59})
# PopAfter 502 0 2187 defaultdict(<class 'int'>, {488: 2169, 504: 2183, 502: 0})
# PopAfter : top_contour : defaultdict(<class 'int'>, {452: 25, 488: 651, 489: 43, 502: 0, 487: 22, 504: 496, 503: 59})
# Detected :  504 2188 defaultdict(<class 'int'>, {488: 2169, 504: 2183, 502: 0})
# PopBefore 502 0 2188 defaultdict(<class 'int'>, {488: 2169, 504: 2188, 502: 0})
# PopBefore : top_contour : defaultdict(<class 'int'>, {452: 25, 488: 651, 489: 43, 502: 0, 487: 22, 504: 496, 503: 59})
# PopAfter 502 0 2188 defaultdict(<class 'int'>, {488: 2169, 504: 2188, 502: 0})
# PopAfter : top_contour : defaultdict(<class 'int'>, {452: 25, 488: 651, 489: 43, 502: 0, 487: 22, 504: 496, 503: 59})
# PopBefore 502 0 2188 defaultdict(<class 'int'>, {488: 2169, 504: 2188, 502: 0})
# PopBefore : top_contour : defaultdict(<class 'int'>, {452: 25, 488: 651, 489: 43, 502: 0, 487: 22, 504: 496, 503: 59})
# PopAfter 502 0 2188 defaultdict(<class 'int'>, {488: 2169, 504: 2188, 502: 0})
# PopAfter : top_contour : defaultdict(<class 'int'>, {452: 25, 488: 651, 489: 43, 502: 0, 487: 22, 504: 496, 503: 59})
# PopBefore 502 0 2188 defaultdict(<class 'int'>, {488: 2169, 504: 2188, 502: 0})
# PopBefore : top_contour : defaultdict(<class 'int'>, {452: 25, 488: 651, 489: 43, 502: 0, 487: 22, 504: 496, 503: 59})
# PopAfter 502 0 2188 defaultdict(<class 'int'>, {488: 2169, 504: 2188, 502: 0})
# PopAfter : top_contour : defaultdict(<class 'int'>, {452: 25, 488: 651, 489: 43, 502: 0, 487: 22, 504: 496, 503: 59})
# Detected :  504 2189 defaultdict(<class 'int'>, {488: 2169, 504: 2188, 502: 0})
# PopBefore 502 0 2189 defaultdict(<class 'int'>, {488: 2169, 504: 2189, 502: 0})
# PopBefore : top_contour : defaultdict(<class 'int'>, {452: 25, 488: 651, 489: 43, 502: 0, 487: 22, 504: 496, 503: 59})
# PopAfter 502 0 2189 defaultdict(<class 'int'>, {488: 2169, 504: 2189, 502: 0})
# PopAfter : top_contour : defaultdict(<class 'int'>, {452: 25, 488: 651, 489: 43, 502: 0, 487: 22, 504: 496, 503: 59})
# PopBefore 502 0 2189 defaultdict(<class 'int'>, {488: 2169, 504: 2189, 502: 0})
# PopBefore : top_contour : defaultdict(<class 'int'>, {452: 25, 488: 651, 489: 43, 502: 0, 487: 22, 504: 496, 503: 59})
# PopAfter 502 0 2189 defaultdict(<class 'int'>, {488: 2169, 504: 2189, 502: 0})
# PopAfter : top_contour : defaultdict(<class 'int'>, {452: 25, 488: 651, 489: 43, 502: 0, 487: 22, 504: 496, 503: 59})
# PopBefore 502 0 2189 defaultdict(<class 'int'>, {488: 2169, 504: 2189, 502: 0})
# PopBefore : top_contour : defaultdict(<class 'int'>, {452: 25, 488: 651, 489: 43, 502: 0, 487: 22, 504: 496, 503: 59})
# PopAfter 502 0 2189 defaultdict(<class 'int'>, {488: 2169, 504: 2189, 502: 0})
# PopAfter : top_contour : defaultdict(<class 'int'>, {452: 25, 488: 651, 489: 43, 502: 0, 487: 22, 504: 496, 503: 59})
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-3-c3cd7db44723> in <module>
#      34 while (cap.isOpened()):
#      35     ret, frame = cap.read()
# ---> 36     cv2.imshow('main',frame)
#      37
#      38     if ret==0:
#
# error: OpenCV(4.1.2) /io/opencv/modules/highgui/src/window.cpp:376: error: (-215:Assertion failed) size.width>0 && size.height>0 in function 'imshow'
